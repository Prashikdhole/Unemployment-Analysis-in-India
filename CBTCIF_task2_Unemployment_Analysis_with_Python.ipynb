# %% [markdown]
# # **Project Name- Unemployment Analysis with Python.**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Name -** Prashik Dhole

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Unemployment refers to the share of the labor force that is without work but available for and seeking employment.The Centre for Monitoring Indian Economy, a private organization (CMIE), estimates India's unemployment rate in India is around 7.45% at present. It is 7.93% in urban India whereas only 7.44% in rural India.The reasons for this unemployment situation are high population, defective education system, excessive burden on agriculture, low productivity in agricultural sector combined with lack of alternative opportunities for agricultural workers, unskilled workforce, etc. Here this dataset contains the unemployment rate of all the states in India.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
import numpy as  np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import plotly.express as px

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_excel('/content/drive/My Drive/Unemployment in India.xlsx')

# %% [markdown]
# ### Dataset First View

# %%
df.head(10)
# Out:
#            Region        Date Frequency  Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh  31-05-2019   Monthly                             3.65
# 1  Andhra Pradesh  30-06-2019   Monthly                             3.05
# 2  Andhra Pradesh  31-07-2019   Monthly                             3.75
# 3  Andhra Pradesh  31-08-2019   Monthly                             3.32
# 4  Andhra Pradesh  30-09-2019   Monthly                             5.17
# 5  Andhra Pradesh  31-10-2019   Monthly                             3.52
# 6  Andhra Pradesh  30-11-2019   Monthly                             4.12
# 7  Andhra Pradesh  31-12-2019   Monthly                             4.38
# 8  Andhra Pradesh  31-01-2020   Monthly                             4.84
# 9  Andhra Pradesh  29-02-2020   Monthly                             5.91
#
#    Estimated Employed  Estimated Labour Participation Rate (%)   Area
# 0          11999139.0                                    43.24  Rural
# ...

# %%
df.tail(10)
# Out:
#           Region        Date Frequency  Estimated Unemployment Rate (%)  \
# 744  West Bengal  30-09-2019   Monthly                             7.79
# 745  West Bengal  31-10-2019   Monthly                             7.83
# 746  West Bengal  30-11-2019   Monthly                             6.61
# 747  West Bengal  31-12-2019   Monthly                             7.24
# 748  West Bengal  31-01-2020   Monthly                             7.27
# 749  West Bengal  29-02-2020   Monthly                             7.55
# 750  West Bengal  31-03-2020   Monthly                             6.67
# 751  West Bengal  30-04-2020   Monthly                            15.63
# 752  West Bengal  31-05-2020   Monthly                            15.22
# 753  West Bengal  30-06-2020   Monthly                             9.86
#
#      Estimated Employed  Estimated Labour Participation Rate (%)   Area
# 744          11158649.0                                    45.74  Urban
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
df.shape
# Out:
# (754, 7)

# %% [markdown]
# ### Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 754 entries, 0 to 753
# Data columns (total 7 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Region                                   740 non-null    object
#  1   Date                                     740 non-null    object
#  2   Frequency                                740 non-null    object
#  3   Estimated Unemployment Rate (%)          740 non-null    float64
#  4   Estimated Employed                       740 non-null    float64
#  5   Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                     740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 41.4+ KB

# %%
df.describe()
# Out:
#        Estimated Unemployment Rate (%)  Estimated Employed  \
# count                       740.000000        7.400000e+02
# mean                         11.787946        7.204460e+06
# std                          10.721298        8.087988e+06
# min                           0.000000        4.942000e+04
# 25%                           4.657500        1.190404e+06
# 50%                           8.350000        4.744178e+06
# 75%                          15.887500        1.127549e+07
# max                          76.740000        4.577751e+07
#
#        Estimated Labour Participation Rate (%)
# count                               740.000000
# mean                                 42.630122
# std                                   8.111094
# min                                  13.330000
# 25%                                  38.062500
# 50%                                  41.160000
# 75%                                  45.505000
# max                                  72.570000

# %% [markdown]
# #### Duplicate Values

# %%
df[df.duplicated()]
# Out:
#     Region Date Frequency  Estimated Unemployment Rate (%)  \
# 360    NaN  NaN       NaN                              NaN
# 361    NaN  NaN       NaN                              NaN
# 362    NaN  NaN       NaN                              NaN
# 363    NaN  NaN       NaN                              NaN
# 364    NaN  NaN       NaN                              NaN
# 365    NaN  NaN       NaN                              NaN
# 366    NaN  NaN       NaN                              NaN
# 367    NaN  NaN       NaN                              NaN
# 368    NaN  NaN       NaN                              NaN
# 369    NaN  NaN       NaN                              NaN
# 370    NaN  NaN       NaN                              NaN
# 371    NaN  NaN       NaN                              NaN
# 372    NaN  NaN       NaN                              NaN
#
#      Estimated Employed  Estimated Labour Participation Rate (%) Area
# ...

# %%
duplicate_value_count = len(df[df.duplicated()])

print('Number of duplicates value present is:',duplicate_value_count)
# Out:
# Number of duplicates value present is: 13

# %% [markdown]
# #### Missing Values/Null Values

# %%
df.isnull().sum()
# Out:
# Region                                     14
# Date                                       14
# Frequency                                  14
# Estimated Unemployment Rate (%)            14
# Estimated Employed                         14
# Estimated Labour Participation Rate (%)    14
# Area                                       14
# dtype: int64

# %%
sns.heatmap(df.isnull(),cmap='inferno',cbar=True)
# Out:
# <Axes: >

# %% [markdown]
# 1.Dataset contains 754 no.of.rows and 7 no.of.columns
#
# 2.Every columns contain the missing value.
#
# 3.there are 98 no.of.missing value present in the dataset.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
df.columns
# Out:
# Index(['Region', 'Date', 'Frequency', 'Estimated Unemployment Rate (%)',
#        'Estimated Employed', 'Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
df.describe(include='all')
# Out:
#                 Region        Date Frequency  Estimated Unemployment Rate (%)  \
# count              740         740       740                       740.000000
# unique              28          14         1                              NaN
# top     Andhra Pradesh  31-10-2019   Monthly                              NaN
# freq                28          55       740                              NaN
# mean               NaN         NaN       NaN                        11.787946
# std                NaN         NaN       NaN                        10.721298
# min                NaN         NaN       NaN                         0.000000
# 25%                NaN         NaN       NaN                         4.657500
# 50%                NaN         NaN       NaN                         8.350000
# 75%                NaN         NaN       NaN                        15.887500
# max                NaN         NaN       NaN                        76.740000
#
# ...

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
for column in df.columns:
  unique_values = df[column].unique()

  print(f"Unique values {column}:{unique_values}")
# Out:
# Unique values Region:['Andhra Pradesh' 'Assam' 'Bihar' 'Chhattisgarh' 'Delhi' 'Goa' 'Gujarat'
#  'Haryana' 'Himachal Pradesh' 'Jammu & Kashmir' 'Jharkhand' 'Karnataka'
#  'Kerala' 'Madhya Pradesh' 'Maharashtra' 'Meghalaya' 'Odisha' 'Puducherry'
#  'Punjab' 'Rajasthan' 'Sikkim' 'Tamil Nadu' 'Telangana' 'Tripura'
#  'Uttar Pradesh' 'Uttarakhand' 'West Bengal' nan 'Chandigarh']
# Unique values Date:['31-05-2019' '30-06-2019' '31-07-2019' '31-08-2019' '30-09-2019'
#  '31-10-2019' '30-11-2019' '31-12-2019' '31-01-2020' '29-02-2020'
#  '31-03-2020' '30-04-2020' '31-05-2020' '30-06-2020' nan]
# Unique values Frequency:['Monthly' nan]
# Unique values Estimated Unemployment Rate (%):[ 3.65  3.05  3.75  3.32  5.17  3.52  4.12  4.38  4.84  5.91  4.06 16.29
#  14.46  0.85  4.29  5.08  4.26  5.79  4.46  4.65  4.66  3.26  3.77  9.38
#   0.    9.27 10.2  13.44 11.    8.87 12.47 12.4  10.16  9.13  9.61 15.39
#  45.09 47.26 20.49  9.82  6.76  4.54  4.64  8.33  6.96  2.77  6.11  9.89
# ...

# %%
df.nunique()
# Out:
# Region                                      28
# Date                                        14
# Frequency                                    1
# Estimated Unemployment Rate (%)            624
# Estimated Employed                         740
# Estimated Labour Participation Rate (%)    626
# Area                                         2
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %%
df.isnull().sum()
# Out:
# Region                                     14
# Date                                       14
# Frequency                                  14
# Estimated Unemployment Rate (%)            14
# Estimated Employed                         14
# Estimated Labour Participation Rate (%)    14
# Area                                       14
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Region                                     0
# Date                                       0
# Frequency                                  0
# Estimated Unemployment Rate (%)            0
# Estimated Employed                         0
# Estimated Labour Participation Rate (%)    0
# Area                                       0
# dtype: int64

# %%
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# <ipython-input-22-b9c6864122be>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])

# %%
df.Date.head()
# Out:
# 0   2019-05-31
# 1   2019-06-30
# 2   2019-07-31
# 3   2019-08-31
# 4   2019-09-30
# Name: Date, dtype: datetime64[ns]

# %%
df['year'] = df['Date'].dt.year

# %%
df['month'] = df['Date'].dt.month

# %%
df.head(10)
# Out:
#            Region       Date Frequency  Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh 2019-05-31   Monthly                             3.65
# 1  Andhra Pradesh 2019-06-30   Monthly                             3.05
# 2  Andhra Pradesh 2019-07-31   Monthly                             3.75
# 3  Andhra Pradesh 2019-08-31   Monthly                             3.32
# 4  Andhra Pradesh 2019-09-30   Monthly                             5.17
# 5  Andhra Pradesh 2019-10-31   Monthly                             3.52
# 6  Andhra Pradesh 2019-11-30   Monthly                             4.12
# 7  Andhra Pradesh 2019-12-31   Monthly                             4.38
# 8  Andhra Pradesh 2020-01-31   Monthly                             4.84
# 9  Andhra Pradesh 2020-02-29   Monthly                             5.91
#
#    Estimated Employed  Estimated Labour Participation Rate (%)   Area  year  \
# 0          11999139.0                                    43.24  Rural  2019
# ...

# %%
df = df.drop(['Frequency'],axis=1)

# %%
df.head(10)
# Out:
#            Region       Date  Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh 2019-05-31                             3.65
# 1  Andhra Pradesh 2019-06-30                             3.05
# 2  Andhra Pradesh 2019-07-31                             3.75
# 3  Andhra Pradesh 2019-08-31                             3.32
# 4  Andhra Pradesh 2019-09-30                             5.17
# 5  Andhra Pradesh 2019-10-31                             3.52
# 6  Andhra Pradesh 2019-11-30                             4.12
# 7  Andhra Pradesh 2019-12-31                             4.38
# 8  Andhra Pradesh 2020-01-31                             4.84
# 9  Andhra Pradesh 2020-02-29                             5.91
#
#    Estimated Employed  Estimated Labour Participation Rate (%)   Area  year  \
# 0          11999139.0                                    43.24  Rural  2019
# 1          11755881.0                                    42.05  Rural  2019
# ...

# %% [markdown]
# ## ***4. EDA***

# %% [markdown]
# #### Chart - 1

# %%
df.head(10)
# Out:
#            Region       Date  Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh 2019-05-31                             3.65
# 1  Andhra Pradesh 2019-06-30                             3.05
# 2  Andhra Pradesh 2019-07-31                             3.75
# 3  Andhra Pradesh 2019-08-31                             3.32
# 4  Andhra Pradesh 2019-09-30                             5.17
# 5  Andhra Pradesh 2019-10-31                             3.52
# 6  Andhra Pradesh 2019-11-30                             4.12
# 7  Andhra Pradesh 2019-12-31                             4.38
# 8  Andhra Pradesh 2020-01-31                             4.84
# 9  Andhra Pradesh 2020-02-29                             5.91
#
#    Estimated Employed  Estimated Labour Participation Rate (%)   Area  year  \
# 0          11999139.0                                    43.24  Rural  2019
# 1          11755881.0                                    42.05  Rural  2019
# ...

# %%
df.Area.value_counts()
# Out:
# Urban    381
# Rural    359
# Name: Area, dtype: int64

# %%
sns.countplot(x='Area',data=df,palette=['pink','silver'])
# Out:
# <Axes: xlabel='Area', ylabel='count'>

# %% [markdown]
# From Above Countplot we get insight that in Urban Area Unemployement is Greater than the Rural Area.

# %% [markdown]
# #### Chart - 2

# %%
df.head(10)
# Out:
#            Region       Date  Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh 2019-05-31                             3.65
# 1  Andhra Pradesh 2019-06-30                             3.05
# 2  Andhra Pradesh 2019-07-31                             3.75
# 3  Andhra Pradesh 2019-08-31                             3.32
# 4  Andhra Pradesh 2019-09-30                             5.17
# 5  Andhra Pradesh 2019-10-31                             3.52
# 6  Andhra Pradesh 2019-11-30                             4.12
# 7  Andhra Pradesh 2019-12-31                             4.38
# 8  Andhra Pradesh 2020-01-31                             4.84
# 9  Andhra Pradesh 2020-02-29                             5.91
#
#    Estimated Employed  Estimated Labour Participation Rate (%)   Area  year  \
# 0          11999139.0                                    43.24  Rural  2019
# 1          11755881.0                                    42.05  Rural  2019
# ...

# %%
df.year.value_counts()
# Out:
# 2019    430
# 2020    310
# Name: year, dtype: int64

# %%
sns.set_style='darkgrid'
fig, ax = plt.subplots(figsize=(12,10))

sns.countplot(x='year',data=df,palette='viridis',ax = ax)
ax.set_title('Unemployement year wise', fontsize=14)
ax.set_xlabel('Type', fontsize=12)
ax.set_ylabel('Count', fontsize=12)
plt.show()

# %% [markdown]
# From above plot we get insight that in the year 2019 Unemployement is More as campared to year 2020 because of Covid-19.

# %% [markdown]
# Chart-3

# %%
df.head(10)
# Out:
#            Region       Date  Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh 2019-05-31                             3.65
# 1  Andhra Pradesh 2019-06-30                             3.05
# 2  Andhra Pradesh 2019-07-31                             3.75
# 3  Andhra Pradesh 2019-08-31                             3.32
# 4  Andhra Pradesh 2019-09-30                             5.17
# 5  Andhra Pradesh 2019-10-31                             3.52
# 6  Andhra Pradesh 2019-11-30                             4.12
# 7  Andhra Pradesh 2019-12-31                             4.38
# 8  Andhra Pradesh 2020-01-31                             4.84
# 9  Andhra Pradesh 2020-02-29                             5.91
#
#    Estimated Employed  Estimated Labour Participation Rate (%)   Area  year  \
# 0          11999139.0                                    43.24  Rural  2019
# 1          11755881.0                                    42.05  Rural  2019
# ...

# %%
df.Region.value_counts()
# Out:
# Andhra Pradesh      28
# Kerala              28
# West Bengal         28
# Uttar Pradesh       28
# Tripura             28
# Telangana           28
# Tamil Nadu          28
# Rajasthan           28
# Punjab              28
# Odisha              28
# Madhya Pradesh      28
# Maharashtra         28
# Karnataka           28
# Jharkhand           28
# Himachal Pradesh    28
# Haryana             28
# Gujarat             28
# Delhi               28
# Chhattisgarh        28
# Bihar               28
# Meghalaya           27
# Uttarakhand         27
# Assam               26
# Puducherry          26
# Goa                 24
# Jammu & Kashmir     21
# Sikkim              17
# Chandigarh          12
# Name: Region, dtype: int64

# %%
sns.countplot(y='Region',data=df)
# Out:
# <Axes: xlabel='count', ylabel='Region'>

# %% [markdown]
# From above chart we get insight that Unemployement is lesser in Chadigarh state and In Andhra Pradesh,Kerala,West Bengal,Uttar Pradesh,Tripura,Telangana,Tamil Nadu,Rajasthan,Punjab,Odisha,Madhya Pradesh,Maharashtra,Karnataka,Jharkhand,Himachal Pradesh,Haryana,Gujarat,Delhi,Chhattisgarh,
# Bihar has highest no of unemployement.

# %% [markdown]
# ####Chart-4

# %%
df.head(10)
# Out:
#            Region       Date  Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh 2019-05-31                             3.65
# 1  Andhra Pradesh 2019-06-30                             3.05
# 2  Andhra Pradesh 2019-07-31                             3.75
# 3  Andhra Pradesh 2019-08-31                             3.32
# 4  Andhra Pradesh 2019-09-30                             5.17
# 5  Andhra Pradesh 2019-10-31                             3.52
# 6  Andhra Pradesh 2019-11-30                             4.12
# 7  Andhra Pradesh 2019-12-31                             4.38
# 8  Andhra Pradesh 2020-01-31                             4.84
# 9  Andhra Pradesh 2020-02-29                             5.91
#
#    Estimated Employed  Estimated Labour Participation Rate (%)   Area  year  \
# 0          11999139.0                                    43.24  Rural  2019
# 1          11755881.0                                    42.05  Rural  2019
# ...

# %%
plt.title('Unemployment Rate based on Area')
sns.scatterplot(y=df['Region'],x=df['Estimated Unemployment Rate (%)'],hue=df['Area'])
# Out:
# <Axes: title={'center': 'Unemployment Rate based on Area'}, xlabel='Estimated Unemployment Rate (%)', ylabel='Region'>

# %% [markdown]
# ####Chart-5

# %%
df.head(10)
# Out:
#            Region       Date  Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh 2019-05-31                             3.65
# 1  Andhra Pradesh 2019-06-30                             3.05
# 2  Andhra Pradesh 2019-07-31                             3.75
# 3  Andhra Pradesh 2019-08-31                             3.32
# 4  Andhra Pradesh 2019-09-30                             5.17
# 5  Andhra Pradesh 2019-10-31                             3.52
# 6  Andhra Pradesh 2019-11-30                             4.12
# 7  Andhra Pradesh 2019-12-31                             4.38
# 8  Andhra Pradesh 2020-01-31                             4.84
# 9  Andhra Pradesh 2020-02-29                             5.91
#
#    Estimated Employed  Estimated Labour Participation Rate (%)   Area  year  \
# 0          11999139.0                                    43.24  Rural  2019
# 1          11755881.0                                    42.05  Rural  2019
# ...

# %%
df.columns
# Out:
# Index(['Region', 'Date', 'Estimated Unemployment Rate (%)',
#        'Estimated Employed', 'Estimated Labour Participation Rate (%)', 'Area',
#        'year', 'month'],
#       dtype='object')

# %%
df['Estimated Unemployment Rate (%)'].unique()
# Out:
# array([ 3.65,  3.05,  3.75,  3.32,  5.17,  3.52,  4.12,  4.38,  4.84,
#         5.91,  4.06, 16.29, 14.46,  0.85,  4.29,  5.08,  4.26,  5.79,
#         4.46,  4.65,  4.66,  3.26,  3.77,  9.38,  0.  ,  9.27, 10.2 ,
#        13.44, 11.  ,  8.87, 12.47, 12.4 , 10.16,  9.13,  9.61, 15.39,
#        45.09, 47.26, 20.49,  9.82,  6.76,  4.54,  4.64,  8.33,  6.96,
#         2.77,  6.11,  9.89,  7.89,  7.31,  7.64, 10.14, 12.56,  9.33,
#        11.07, 17.18, 12.5 , 15.84, 11.11, 16.97, 13.48, 13.81, 15.18,
#        20.69, 22.76, 21.14,  2.91,  5.45, 10.98,  1.98,  3.61,  7.21,
#        23.71,  3.54,  5.38, 15.91, 20.  ,  2.88,  4.77,  4.58,  3.7 ,
#         6.29,  4.91,  4.68,  3.46,  5.35,  6.64,  7.59, 12.  , 14.58,
#         1.41, 14.54, 23.08, 16.22, 30.94, 16.36, 24.17, 16.59, 29.56,
#        16.21, 27.19, 23.92, 41.61, 34.22, 35.57, 13.68, 11.43, 20.59,
#        18.56, 15.98, 15.81, 22.86, 19.46, 16.67, 15.42, 17.71,  2.13,
# ...

# %%
df[df['Estimated Unemployment Rate (%)']>50].Region.value_counts()
# Out:
# Jharkhand     3
# Puducherry    3
# Tamil Nadu    1
# Bihar         1
# Name: Region, dtype: int64

# %%
plt.title('States with High Unemployment Rate')
df1=df[df['Estimated Unemployment Rate (%)']>50]
sns.scatterplot(y=df['Region'],x=df1['Estimated Unemployment Rate (%)'],hue=df['Area'])
# Out:
# <Axes: title={'center': 'States with High Unemployment Rate'}, xlabel='Estimated Unemployment Rate (%)', ylabel='Region'>

# %% [markdown]
# From above scatter plot we get insight that in Puducherry State both rural and urban have the highest unemployement rate.

# %% [markdown]
# ####Chart-6

# %%
df.columns

# %%
df['Estimated Labour Participation Rate (%)'].unique()
# Out:
# array([43.24, 42.05, 43.5 , 43.97, 44.68, 43.01, 41.  , 45.14, 43.46,
#        42.83, 40.66, 36.03, 38.16, 53.76, 57.39, 43.87, 48.21, 45.83,
#        55.67, 40.76, 46.64, 54.9 , 40.17, 47.05, 50.  , 34.38, 39.75,
#        39.71, 39.66, 36.85, 38.57, 40.31, 37.51, 37.25, 37.54, 37.28,
#        38.88, 38.63, 38.5 , 37.4 , 42.89, 43.71, 43.53, 42.55, 43.38,
#        46.28, 43.56, 42.59, 42.03, 45.05, 44.98, 39.43, 35.56, 38.66,
#        42.33, 35.74, 40.53, 35.21, 40.68, 37.9 , 42.71, 37.08, 38.36,
#        35.84, 37.45, 30.21, 34.65, 29.22, 39.16, 38.19, 39.81, 39.61,
#        35.78, 40.36, 44.09, 38.7 , 35.36, 36.11, 45.36, 33.71, 52.03,
#        50.12, 54.21, 50.57, 51.01, 52.27, 54.55, 51.51, 54.07, 53.48,
#        52.06, 34.77, 46.31, 47.72, 45.12, 45.23, 42.17, 48.23, 44.72,
#        46.07, 42.48, 47.4 , 43.74, 45.37, 41.4 , 49.85, 42.78, 48.53,
#        44.23, 41.18, 44.91, 45.02, 42.81, 48.5 , 44.05, 45.11, 42.45,
# ...

# %%
df[df['Estimated Labour Participation Rate (%)']>40]
# Out:
#              Region       Date  Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh 2019-05-31                             3.65
# 1    Andhra Pradesh 2019-06-30                             3.05
# 2    Andhra Pradesh 2019-07-31                             3.75
# 3    Andhra Pradesh 2019-08-31                             3.32
# 4    Andhra Pradesh 2019-09-30                             5.17
# ..              ...        ...                              ...
# 748     West Bengal 2020-01-31                             7.27
# 749     West Bengal 2020-02-29                             7.55
# 750     West Bengal 2020-03-31                             6.67
# 751     West Bengal 2020-04-30                            15.63
# 752     West Bengal 2020-05-31                            15.22
#
#      Estimated Employed  Estimated Labour Participation Rate (%)   Area  year
# 0            11999139.0                                    43.24  Rural  2019
# ...

# %%
plt.title('States with High Labour Participation rate')
df1=df[df['Estimated Labour Participation Rate (%)']>50]r̥
sns.scatterplot(y=df['Region'],x=df1['Estimated Labour Participation Rate (%)'],hue=df['Area'])
# Out:
# <Axes: title={'center': 'States with High Labour Participation rate'}, xlabel='Estimated Labour Participation Rate (%)', ylabel='Region'>

# %% [markdown]
# From above chart we get insight that Maharashtra state has highest labour participation rate in Rural area. where Tripura state has also high labour participation in both Rural and Urban area.

# %% [markdown]
# ####Chart-7

# %%
df=df.drop(['month'],axis=1)
by_year=df.groupby(['year']).mean().round()
by_year.style.background_gradient(cmap='Blues_r')
# Out:
# <ipython-input-85-2ea08c4c785c>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   by_year=df.groupby(['year']).mean().round()
# <style type="text/css">
# #T_e2959_row0_col0, #T_e2959_row1_col1, #T_e2959_row1_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_e2959_row0_col1, #T_e2959_row0_col2, #T_e2959_row1_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_e2959" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2959_level0_col0" class="col_heading level0 col0" >Estimated Unemployment Rate (%)</th>
#       <th id="T_e2959_level0_col1" class="col_heading level0 col1" >Estimated Employed</th>
# ...

# %% [markdown]
# ####chart-8

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),annot=True)
# Out:
# <ipython-input-92-7d18f16fca9f>:2: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# <Axes: >

# %% [markdown]
# ####Load other File

# %%
df2 = pd.read_excel('/content/drive/My Drive/Unemployment_Rate_upto_11_2020.xlsx')

# %%
df2.head(10)
# Out:
#            Region        Date Frequency  Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh  31-01-2020         M                             5.48
# 1  Andhra Pradesh  29-02-2020         M                             5.83
# 2  Andhra Pradesh  31-03-2020         M                             5.79
# 3  Andhra Pradesh  30-04-2020         M                            20.51
# 4  Andhra Pradesh  31-05-2020         M                            17.43
# 5  Andhra Pradesh  30-06-2020         M                             3.31
# 6  Andhra Pradesh  31-07-2020         M                             8.34
# 7  Andhra Pradesh  31-08-2020         M                             6.96
# 8  Andhra Pradesh  30-09-2020         M                             6.40
# 9  Andhra Pradesh  31-10-2020         M                             6.59
#
#    Estimated Employed  Estimated Labour Participation Rate (%) Region.1  \
# 0            16635535                                    41.02    South
# ...

# %%
unemployment = df2[['Region', 'Region.1', 'Estimated Unemployment Rate (%)', 'Estimated Employed',
                    'Estimated Labour Participation Rate (%)']]
unemployment = unemployment.groupby(['Region.1', 'Region'])['Estimated Unemployment Rate (%)'].mean().reset_index()
fig = px.sunburst(unemployment, path=['Region.1', 'Region'], values='Estimated Unemployment Rate (%)',
                  title='Unemployment rate in each State and Region',height=850)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
